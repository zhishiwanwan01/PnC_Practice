# %%
# %matplotlib widget
import os
os.chdir('/workspace/search_based_planner')

# %%
# %run a_star.py
# Out:
# Grid Map Info:
# min_x: 0
# min_y: 0
# max_x: 157
# max_y: 88
# x_length: 78
# y_length: 44
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
